# %%
import pandas as pd

# %%
# read the csv file of all schools and the school rank
df_school = pd.read_csv("school locations.csv", encoding='cp1252')
df_school_rank = pd.read_csv('school_rank.csv')

# %%
# rename the column in school rank so that they have a same column to join on
df_school_rank.rename(columns={'School': 'School_Name'}, inplace=True)
pd.merge(df_school_rank, df_school, on='School_Name', how='inner')
# Out:
#      rank                     School_Name         Location MedianVCE Score  \
# 0       1        Haileybury Girls College      Keysborough              37
# 1       2                  Bialik College    Hawthorn East              37
# 2       3      Ballarat Clarendon College         Ballarat              37
# 3       5             Huntingtower School   Mount Waverley              37
# 4       7          Leibler Yavneh College      Elsternwick              37
# ..    ...                             ...              ...             ...
# 410   575               Parkville College        Parkville               0
# 411   576   Peter Lalor Secondary College            Lalor               0
# 412   580               River Nile School  North Melbourne               0
# 413   585  The Lakes South Morang College     South Morang               0
# 414   632         Sholem Aleichem College      Elsternwick
#
#     VCE40+% Education_Sector  Entity_Type  SCHOOL_NO School_Type  \
# 0      37.2      Independent            2       2009     Pri/Sec
# 1      32.6      Independent            2       1626     Pri/Sec
# 2      32.5      Independent            2        278     Pri/Sec
# 3      31.6      Independent            2       1267     Pri/Sec
# 4      29.4      Independent            2       1609     Pri/Sec
# ..      ...              ...          ...        ...         ...
# 410       0       Government            1       8916     Special
# 411       0       Government            1       7217   Secondary
# 412       0      Independent            2       2111     Special
# 413       0       Government            1       8846     Pri/Sec
# 414              Independent            2       1729     Primary
#
#     School_Status  ... Postal_Address_Line_1 Postal_Address_Line_2  \
# 0               O  ...   855 Springvale Road                   NaN
# 1               O  ...       429 Auburn Road                   NaN
# 2               O  ...     1425 Sturt Street                   NaN
# 3               O  ...            PO Box 192                   NaN
# 4               O  ...            PO Box 164                   NaN
# ..            ...  ...                   ...                   ...
# 410             O  ...       930 Park Street                   NaN
# 411             O  ...          P O Box 1250                   NaN
# 412             O  ...               Level 1      117 Capel Street
# 413             O  ...           P O Box 207                   NaN
# 414             O  ...        11 Sinclair St                   NaN
#
#          Postal_Town Postal_State  Postal_Postcode Full_Phone_No LGA_ID  \
# 0        KEYSBOROUGH          VIC             3173  03 9213 2222    267
# 1      HAWTHORN EAST          VIC             3122  03 9822 7981    111
# 2           BALLARAT          VIC             3350  03 5330 8200     57
# 3     MOUNT WAVERLEY          VIC             3149  03 9807 8888    497
# 4    CAULFIELD SOUTH          VIC             3162  03 9528 4911    231
# ..               ...          ...              ...           ...    ...
# 410        Parkville          VIC             3052  03 5421 3100    460
# 411           EPPING          VIC             3076  03 9464 0122    707
# 412  NORTH MELBOURNE          VIC             3051  03 9329 8425    460
# 413     South Morang          VIC             3752  03 9401 3919    707
# 414      ELSTERNWICK          VIC             3185  03 8527 3000    231
#
#                   LGA_Name          X         Y
# 0    Greater Dandenong (C)  145.14477 -37.99555
# 1           Boroondara (C)  145.04337 -37.84227
# 2             Ballarat (C)  143.83365 -37.55965
# 3               Monash (C)  145.13629 -37.87674
# 4            Glen Eira (C)  145.00663 -37.89287
# ..                     ...        ...       ...
# 410          Melbourne (C)  144.94736 -37.77682
# 411         Whittlesea (C)  145.01316 -37.66691
# 412          Melbourne (C)  144.95509 -37.80519
# 413         Whittlesea (C)  145.07568 -37.63494
# 414          Glen Eira (C)  145.00120 -37.88229
#
# [415 rows x 25 columns]

# %%
# select the useful columns
school_rank_more_info = pd.merge(df_school_rank, df_school, on='School_Name', how='inner')[['rank', 'School_Name', 'Location', 'MedianVCE Score', 'VCE40+%', 'Education_Sector', 'School_Type', 'Postal_Postcode']]

# %%
school_rank_more_info['School_Type'].groupby(school_rank_more_info['School_Type']).count()
# Out:
# School_Type
# Pri/Sec      140
# Primary        4
# Secondary    268
# Special        3
# Name: School_Type, dtype: int64

# %%
# save to school_rank_more_info.csv
school_rank_more_info.to_csv('school_rank_more_info.csv', index=False)
