# %%
import pandas as pd

# %%
# read the csv file of all schools and the school rank
df_school = pd.read_csv("../data/raw/school_remove_selective.csv", encoding='cp1252')
df_primary_school_rank = pd.read_csv('../data/raw/primary_school_rank.csv')

# %%
# rename the column in school rank so that they have a same column to join on
df_primary_school_rank.rename(columns={'School name': 'School_Name'}, inplace=True)
df_primary_school_rank_more_info = pd.merge(df_primary_school_rank, df_school, on='School_Name', how='inner')

# %%
df_primary_school_rank_more_info = df_primary_school_rank_more_info.drop_duplicates()

# %%
df_primary_school_rank_more_info
# Out:
#      rank                    School_Name  Search Volume  \
# 0       1   Presbyterian Ladies' College           2300
# 1       2         Serpell Primary School           1000
# 2       3             Haileybury College           1800
# 3       4            Huntingtower School           2000
# 4       5  Beverley Hills Primary School           1000
# ..    ...                            ...            ...
# 289   143         Milgate Primary School           1300
# 290   144              Kingswood College           1500
# 291   145       Fairfield Primary School           1400
# 292   146   Newport Lakes Primary School            250
# 293   149         Southern Cross Grammar           1000
#
#                   Keyword Searched  School Type          Location  Postcode  \
# 0      presbyterian ladies college  Independent           Burwood      3125
# 1           serpell primary school   Government       Templestowe      3106
# ...

# %%
# select the useful columns
df_primary_school_rank_more_info = df_primary_school_rank_more_info[['rank', 'School_Name', 'Location', 'Education_Sector', 'School_Type', 'Postal_Postcode','X', 'Y']]

# %%
df_primary_school_rank_more_info ['School_Type'].groupby(df_primary_school_rank_more_info ['School_Type']).count()
# Out:
# School_Type
# Pri/Sec     48
# Primary    246
# Name: School_Type, dtype: int64

# %%
# save to school_rank_more_info.csv
df_primary_school_rank_more_info.to_csv('../data/raw/primary_school_rank_more_info.csv', index=False)
