# %%
# change directory
import os
import pandas as pd
os.chdir('../scripts/')

# %%
# sdf = pd.read_csv("../data/raw/station.csv")

# %%
from utils import *

# %%
create_path()
# Out:
# Already Create Paths

# %%
partition_domain_df(domain_df, procs=PROCS)

# %%
domain_nearest_stops()

# %%
df = domain_output_df()
df
# Out:
#        property_id                   street     suburb state  postcode  \
# 0         13671355  104/300 Swanston Street  MELBOURNE   VIC      3000
# 1         14868152   101/25-33 Wills Street  MELBOURNE   VIC      3000
# 2         15572564  2108/288 Spencer Street  MELBOURNE   VIC      3000
# 3         15831027  2201/288 Spencer Street  MELBOURNE   VIC      3000
# 4         15996004  502/5 Sutherland Street  MELBOURNE   VIC      3000
# ...            ...                      ...        ...   ...       ...
# 30259     15951739          64 Dixon Street  INVERLOCH   VIC      3996
# 30260     16006035   16B Sandy Mount Avenue  INVERLOCH   VIC      3996
# 30261     16006402      25A Veronica Street  INVERLOCH   VIC      3996
# 30262     16040296      14 Inverloch Parade  INVERLOCH   VIC      3996
# 30263     16071116           6 Bruce Street  INVERLOCH   VIC      3996
#
#         latitude   longitude             price  bedrooms  bathrooms  parking  \
# ...
